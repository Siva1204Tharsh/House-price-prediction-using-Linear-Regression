# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("dataset.csv")
dataset.head(10)
# Out:
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000
# 5  14115  143000
# 6  10084  307000
# 7  10382  200000
# 8   6120  129900
# 9   7420  118000

# %%
dataset.plot(kind='scatter', x='area', y='price')
plt.xlabel("Area")
plt.ylabel("Price of Home")
plt.show()

# %%
dataset.isnull().any()
X=dataset.drop('price',axis=1)
y=dataset.price

# %%
import scipy.stats as stats

results = stats.linregress(X, y)
rValue = results.rvalue
rValue
print(results)
# Out:
# LinregressResult(slope=2.0999719517076745, intercept=158836.1518968766, rvalue=0.2638433538714056, pvalue=1.1231391549186287e-24, stderr=0.20105751769847532, intercept_stderr=2914.7174978048542)

# %%
result2=stats.kendalltau(X, y)
print(result2)
# Out:
# SignificanceResult(statistic=0.31417440818989145, pvalue=4.800465724353403e-72)

# %%
from sklearn.linear_model import LinearRegression
MODEL=LinearRegression()
MODEL.fit(X,y)
print(MODEL.coef_)
MODEL.intercept_
y_pred=MODEL.predict(X)
# Out:
# [2.09997195]

# %%
plt.scatter(X, y, color='blue', marker='o')
plt.plot(X, y_pred, color='red')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()
